# %% [markdown]
# **Welcome to Introduction to TensorFlow!**

# %% [markdown]
# In this lab, we will be understanding how to work with TensorFlow layers and functions.

# %% [markdown]
# We begin with importing the libraries required to continue further.

# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Then, we load the data into the memory.

# %%
data = pd.read_csv('data.csv')

# %% [markdown]
# If we look at the dataframe's properties, we see that there are many columns and rows.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %% [markdown]
# In this example, we will start small. Let's select two columns to proceed with building a model.
#
#
# This leads to building an equation of type:
#
#
# y = f(x1,x2)

# %%
x = data[['radius_mean', 'perimeter_mean']]
y = data[['diagnosis']]

# %% [markdown]
# Let's have a look at what we have selected

# %%
x.head()
# Out:
#    radius_mean  perimeter_mean
# 0        17.99          122.80
# 1        20.57          132.90
# 2        19.69          130.00
# 3        11.42           77.58
# 4        20.29          135.10

# %% [markdown]
# Always check for null values

# %%
print(x.isna().sum())
# Out:
# radius_mean       0
# perimeter_mean    0
# dtype: int64

# %% [markdown]
# You can also view the general statistics of your dataset

# %%
x.describe()
# Out:
#        radius_mean  perimeter_mean
# count   569.000000      569.000000
# mean     14.127292       91.969033
# std       3.524049       24.298981
# min       6.981000       43.790000
# 25%      11.700000       75.170000
# 50%      13.370000       86.240000
# 75%      15.780000      104.100000
# max      28.110000      188.500000

# %% [markdown]
# We had a look at our inputs. Now let's have a peek at the labels.

# %%
y.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %% [markdown]
# Normalization brings your dataset into a more managable range. We can apply z-scoring to normalize the dataset.
#
# The formula for z-scoring is:
#
# normalized_data = (data - mean) / standard_deviation

# %%
# Get the mean and standard deviation
stats = x.describe().T
mu, sigma = stats['mean'], stats['std']

# %%
# Normalize the data
x_norm = (x-mu)/sigma
x_norm.head()
# Out:
#    radius_mean  perimeter_mean
# 0     1.096100        1.268817
# 1     1.828212        1.684473
# 2     1.578499        1.565126
# 3    -0.768233       -0.592166
# 4     1.748758        1.775011

# %% [markdown]
# The inputs looks nice and clean now. But our labels are still tricky- they contain values like 'M' and 'B', but tensors work only on numbers.
#
# We will now proceed to convert 'M' and 'B' into 1 and 0 so that we can build a classification model distributing the data into 1 and 0. We can then reverse map the predictions to infer 'M' or 'B'.

# %% [markdown]
# To encode our values from 'M' and 'B' into 1 and 0, we will use lambda functions, and then apply the function logic to every element of our dataframe.

# %%
rule = lambda val: 1 if val=='M' else 0

# %%
y=y['diagnosis'].apply(rule)

# %% [markdown]
# Let's check out the result of our encoding

# %%
y.tail()
# Out:
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, dtype: int64

# %% [markdown]
# Now that it's all numbers, we can begin designing our first tensorflow network.
#
# We begin with defining 'Hyperparameters'. Hyperparameters are values that you can fluctuate to alter model outputs. Parameters are from the dataset- every thing else that you can modify to alter the model results are hyperparamters!

# %% [markdown]
# In this example, we have 3 hyperparameters. Epochs tell us how long the model will train for or iterations. Batch size is the number of rows consumed in each step. Learning rate helps us reduce the loss over a period of time.

# %%
HP_epochs = 200
HP_batch_size = 16
HP_lr = 0.001

# %% [markdown]
# Then, we divide our dataset into training and scoring datasets. Training dataset will be used to build/train the model, while scoring dataset will be used to test the model.

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x_norm,y,random_state=42)

# %% [markdown]
# Now, let's design our model. We are beginning with just 1 layer. This is a fully connected layer, represented as 'Dense' in TensorFlow. Using only one layer gives us the following model equation:
#
#
# y = weight1 * x1 + weight2 * x2 + bias

# %%
model = tf.keras.Sequential([
    keras.layers.Dense(1)
])

# %% [markdown]
# The next step is to compile the model. Compiling specifies how the loss will be calculated, and optimized to yield a hopefully lower loss. This is where we use learning rate!

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=HP_lr)
my_error = 'mean_absolute_error'
model.compile(
    optimizer=my_optimizer,
    loss=my_error)

# %% [markdown]
# Notice how we could just use 'mean_absolute_error' as a string! TensorFlow allows us to use many such strings as predefined deep learning entities! Loss functions, optimization functions and metrics are such examples.

# %%
# Do Not Uncomment- this is an alternate example
# FOR READING ONLY
# Note: instead of our own optimizer,
# we could have also defined our optimizer as
# my_optimizer = 'adam'

# %% [markdown]
# Now, we will train the model. Training is the process of fitting a curve/algebric equation through the dataset. This equation is then used to predict future inputs.
#
# We are using the EPOCH hyperparameter here.

# %%
model.fit(xtrain, ytrain, epochs=HP_epochs)
# Out:
# Epoch 1/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5338
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5063
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4854
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4515
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4354
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4300
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4041
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3905
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3720
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3558
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3489
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3336
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3119
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2958
# Epoch 15/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3070
# Epoch 16/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2811
# Epoch 17/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2855
# Epoch 18/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2518
# Epoch 19/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2790
# Epoch 20/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2785
# Epoch 21/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2744
# Epoch 22/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2801
# Epoch 23/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2609
# Epoch 24/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2667
# Epoch 25/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2647
# Epoch 26/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2688
# Epoch 27/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2658
# Epoch 28/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2711
# Epoch 29/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2649
# Epoch 30/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2650
# Epoch 31/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2576
# Epoch 32/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2744
# Epoch 33/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2650
# Epoch 34/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2630
# Epoch 35/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2397
# Epoch 36/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2489
# Epoch 37/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2592
# Epoch 38/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2571
# Epoch 39/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2627
# Epoch 40/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2656
# Epoch 41/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2663
# Epoch 42/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2659
# Epoch 43/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2781
# Epoch 44/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2599
# Epoch 45/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2559
# Epoch 46/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2451
# Epoch 47/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2551
# Epoch 48/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2648
# Epoch 49/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2648
# Epoch 50/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2631
# Epoch 51/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2577
# Epoch 52/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2656
# Epoch 53/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2499
# Epoch 54/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2547
# Epoch 55/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2582
# Epoch 56/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2528
# Epoch 57/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2611
# Epoch 58/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2630
# Epoch 59/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2489
# Epoch 60/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2566
# Epoch 61/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2484
# Epoch 62/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2633
# Epoch 63/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2497
# Epoch 64/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2503
# Epoch 65/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2675
# Epoch 66/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2705
# Epoch 67/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2567
# Epoch 68/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2821
# Epoch 69/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2644
# Epoch 70/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2606
# Epoch 71/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2451
# Epoch 72/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2515
# Epoch 73/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2589
# Epoch 74/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2566
# Epoch 75/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2575
# Epoch 76/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2616
# Epoch 77/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2725
# Epoch 78/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2746
# Epoch 79/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2537
# Epoch 80/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2510
# Epoch 81/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2578
# Epoch 82/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2763
# Epoch 83/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2606
# Epoch 84/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2490
# Epoch 85/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2553
# Epoch 86/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2582
# Epoch 87/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2598
# Epoch 88/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2630
# Epoch 89/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2732
# Epoch 90/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2612
# Epoch 91/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2586
# Epoch 92/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2622
# Epoch 93/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2532
# Epoch 94/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2431
# Epoch 95/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2499
# Epoch 96/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2482
# Epoch 97/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2708
# Epoch 98/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2698
# Epoch 99/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2604
# Epoch 100/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2668
# Epoch 101/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2553
# Epoch 102/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2392
# Epoch 103/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2507
# Epoch 104/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2478
# Epoch 105/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2555
# Epoch 106/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2562
# Epoch 107/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2641
# Epoch 108/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2661
# Epoch 109/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2636
# Epoch 110/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2549
# Epoch 111/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2513
# Epoch 112/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2560
# Epoch 113/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2572
# Epoch 114/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2535
# Epoch 115/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2696
# Epoch 116/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2448
# Epoch 117/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2674
# Epoch 118/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2586
# Epoch 119/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2792
# Epoch 120/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2560
# Epoch 121/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2635
# Epoch 122/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2614
# Epoch 123/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2498
# Epoch 124/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2494
# Epoch 125/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2398
# Epoch 126/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2454
# Epoch 127/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2616
# Epoch 128/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2558
# Epoch 129/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2528
# Epoch 130/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2526
# Epoch 131/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2561
# Epoch 132/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2415
# Epoch 133/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2600
# Epoch 134/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2628
# Epoch 135/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2761
# Epoch 136/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2690
# Epoch 137/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2563
# Epoch 138/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2570
# Epoch 139/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2446
# Epoch 140/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2484
# Epoch 141/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2533
# Epoch 142/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2635
# Epoch 143/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2662
# Epoch 144/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2719
# Epoch 145/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2558
# Epoch 146/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2407
# Epoch 147/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2568
# Epoch 148/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2687
# Epoch 149/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2597
# Epoch 150/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2568
# Epoch 151/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2517
# Epoch 152/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2626
# Epoch 153/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2591
# Epoch 154/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2677
# Epoch 155/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2668
# Epoch 156/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2540
# Epoch 157/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2498
# Epoch 158/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2669
# Epoch 159/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2536
# Epoch 160/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2511
# Epoch 161/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2491
# Epoch 162/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2621
# Epoch 163/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2753
# Epoch 164/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2461
# Epoch 165/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2600
# Epoch 166/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2568
# Epoch 167/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2606
# Epoch 168/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2537
# Epoch 169/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2576
# Epoch 170/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2554
# Epoch 171/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2537
# Epoch 172/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2629
# Epoch 173/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2467
# Epoch 174/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2552
# Epoch 175/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2555
# Epoch 176/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2535
# Epoch 177/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2663
# Epoch 178/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2601
# Epoch 179/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2612
# Epoch 180/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2563
# Epoch 181/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2811
# Epoch 182/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2588
# Epoch 183/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2604
# Epoch 184/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2777
# Epoch 185/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2489
# Epoch 186/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2496
# Epoch 187/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2622
# Epoch 188/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2551
# Epoch 189/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2628
# Epoch 190/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2475
# Epoch 191/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2536
# Epoch 192/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2490
# Epoch 193/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2554
# Epoch 194/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2675
# Epoch 195/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2685
# Epoch 196/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2695
# Epoch 197/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2600
# Epoch 198/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2703
# Epoch 199/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2449
# Epoch 200/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2673

# %% [markdown]
# Let's have a look at the model we designed

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11 (48.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 8 (36.00 B)

# %% [markdown]
# The trainable parameters can be calculated in the following manner:
#
# We have two types of trainable parameters in this example- weights and bias.
#
# Weights are calculated for each input and output. <br/>
#
# Hence, total weights = inputs * output
#
# Bias is calculated for each output. Total bias = output

# %% [markdown]
# Here, we have 2 inputs (x1 and x2), and 1 output (y).
#
#
# Total parameters = weights + bias
#
# Total parameters = input * output + output

# %% [markdown]
# In our case, this happens to be
#
# Total parameters = 2 * 1 + 1
#
# = 3

# %% [markdown]
# <br/>
# Now let's get some predictions from our model, and have a look at them.

# %%
train_predictions = model.predict(xtrain)
test_predictions = model.predict(xtest)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
train_predictions[:5]
# Out:
# array([[0.15785019],
#        [0.25020063],
#        [0.18539312],
#        [0.72263414],
#        [1.0164073 ]], dtype=float32)

# %% [markdown]
# The model outputs don't look like 1 and 0- they are values calculated with the help of our trained model
# <br/><br/>
# y = weight1*x1 + weight2*x2 + bias

# %% [markdown]
# We will convert them now into 1 and 0, for the ease of calculation, and the ease of decoding to 'M' and 'B'.

# %%
rule = lambda val: 1 if val>=0.5 else 0

# %%
train_predictions = [ rule(prediction) for prediction in train_predictions]
test_predictions = [ rule(prediction) for prediction in test_predictions]

# %% [markdown]
# Let's have a look at the transformed labels

# %%
test_predictions[:5]
# Out:
# array([[0.13368517],
#        [0.8350795 ],
#        [0.4683416 ],
#        [0.13525486],
#        [0.02927271]], dtype=float32)

# %% [markdown]
# Now let's check how well our model performed. <br/><br/>
# Accuracy is an easy equation- out of all guesses, how many did our model get right? A 100% accuracy is represented by 1, and 0% accuracy as 0.

# %% [markdown]
# How did our model perform on the dataset that it was trained on?

# %%
print(accuracy_score(train_predictions,ytrain))
# Out:
# 0.8544600938967136

# %%
# or in %
print(str(accuracy_score(train_predictions,ytrain)*100) + "%")
# Out:
# 85.44600938967136%

# %% [markdown]
# How did our model perform on unknown data?

# %%
accuracy_score(test_predictions,ytest)
# Out:
# 0.8811188811188811

# %% [markdown]
# Are the values close enough? Are they too far away from each other? Is this overfitting? Is this underfitting? We will answer these questions slowly over the next few labs!

# %% [markdown]
# **Conclusion**

# %% [markdown]
# In this lab, we learnt the following:
#
#
#
# *   Read the data and clean it
# *   Break the data into inputs and labels
# *   Normalize the inputs and encode the labels if required
# *   Distribute the data into training and scoring datasets
# *   Design the neural network and compile it
# *   Train the model with training dataset
# *   Test the model with scoring dataset
# *   Use metrics (such as accuracy) to validate the dataset
# <br/><br/>
